# %%
#Yusuf Kelashipour 2024, Aug
import requests

# %%
standings_url = "https://fbref.com/en/comps/9/Premier-League-Stats" #Premier league data sheet

# %%
data = requests.get(standings_url) #Downloads the html of the above data link

# %%
from bs4 import BeautifulSoup #library for parsing html

# %%
soup = BeautifulSoup(data.text)

# %%
league_table = soup.select('table.stats_table')[0] #narrow down our html to just the league tables

# %%
links = league_table.find_all('a') #search for all 'a' tags as these hold each teams individual statistics

# %%
links = [l.get("href") for l in links]

# %%
links = [l for l in links if '/squads/' in l] #isolate all links for each teams stats

# %%
links
# Out:
# ['/en/squads/b8fd03ef/Manchester-City-Stats',
#  '/en/squads/d07537b9/Brighton-and-Hove-Albion-Stats',
#  '/en/squads/18bb7c10/Arsenal-Stats',
#  '/en/squads/822bd0ba/Liverpool-Stats',
#  '/en/squads/cd051869/Brentford-Stats',
#  '/en/squads/8602292d/Aston-Villa-Stats',
#  '/en/squads/4ba7cbea/Bournemouth-Stats',
#  '/en/squads/e4a775cb/Nottingham-Forest-Stats',
#  '/en/squads/361ca564/Tottenham-Hotspur-Stats',
#  '/en/squads/b2b47a98/Newcastle-United-Stats',
#  '/en/squads/fd962109/Fulham-Stats',
#  '/en/squads/cff3d9bb/Chelsea-Stats',
#  '/en/squads/19538871/Manchester-United-Stats',
#  '/en/squads/7c21e445/West-Ham-United-Stats',
#  '/en/squads/a2d435b3/Leicester-City-Stats',
#  '/en/squads/b74092de/Ipswich-Town-Stats',
#  '/en/squads/8cec06e1/Wolverhampton-Wanderers-Stats',
#  '/en/squads/47c64c55/Crystal-Palace-Stats',
#  '/en/squads/33c895d4/Southampton-Stats',
#  '/en/squads/d3fd31cc/Everton-Stats']

# %%
team_urls = [f"https://fbref.com{l}" for l in links] #adds the missing beginning of url to each teams urls

# %%
team_urls
# Out:
# ['https://fbref.com/en/squads/b8fd03ef/Manchester-City-Stats',
#  'https://fbref.com/en/squads/d07537b9/Brighton-and-Hove-Albion-Stats',
#  'https://fbref.com/en/squads/18bb7c10/Arsenal-Stats',
#  'https://fbref.com/en/squads/822bd0ba/Liverpool-Stats',
#  'https://fbref.com/en/squads/cd051869/Brentford-Stats',
#  'https://fbref.com/en/squads/8602292d/Aston-Villa-Stats',
#  'https://fbref.com/en/squads/4ba7cbea/Bournemouth-Stats',
#  'https://fbref.com/en/squads/e4a775cb/Nottingham-Forest-Stats',
#  'https://fbref.com/en/squads/361ca564/Tottenham-Hotspur-Stats',
#  'https://fbref.com/en/squads/b2b47a98/Newcastle-United-Stats',
#  'https://fbref.com/en/squads/fd962109/Fulham-Stats',
#  'https://fbref.com/en/squads/cff3d9bb/Chelsea-Stats',
#  'https://fbref.com/en/squads/19538871/Manchester-United-Stats',
#  'https://fbref.com/en/squads/7c21e445/West-Ham-United-Stats',
#  'https://fbref.com/en/squads/a2d435b3/Leicester-City-Stats',
# ...

# %%
team_url = team_urls[0]

# %%
data = requests.get(team_url)

# %%
import pandas as pd

matches = pd.read_html(data.text , match="Scores & Fixtures")
# Out:
# /var/folders/j5/65jgd4793tvg7jn64hwhwwhm0000gn/T/ipykernel_2291/1071633447.py:3: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text , match="Scores & Fixtures")

# %%
matches[0]
# Out:
#           Date   Time                 Comp                Round  Day Venue  \
# 0   2024-08-10  15:00  FA Community Shield  FA Community Shield  Sat  Home
# 1   2024-08-18  16:30       Premier League          Matchweek 1  Sun  Away
# 2   2024-08-24  15:00       Premier League          Matchweek 2  Sat  Home
# 3   2024-08-31  17:30       Premier League          Matchweek 3  Sat  Away
# 4   2024-09-14  15:00       Premier League          Matchweek 4  Sat  Home
# 5   2024-09-17  19:45              EFL Cup          Third round  Tue  Home
# 6   2024-09-18  20:00         Champions Lg         League phase  Wed  Home
# 7   2024-09-22  16:30       Premier League          Matchweek 5  Sun  Home
# 8   2024-09-28  12:30       Premier League          Matchweek 6  Sat  Away
# 9   2024-10-01  21:00         Champions Lg         League phase  Tue  Away
# 10  2024-10-05  15:00       Premier League          Matchweek 7  Sat  Home
# ...

# %%
soup = BeautifulSoup(data.text)

# %%
links = soup.find_all('a')

# %%
links = [l.get("href") for l in links]

# %%
links = [l for l in links if l and 'all_comps/shooting/' in l] #finds the shooting statistics url for each team

# %%
links
# Out:
# ['/en/squads/b8fd03ef/2024-2025/matchlogs/all_comps/shooting/Manchester-City-Match-Logs-All-Competitions',
#  '/en/squads/b8fd03ef/2024-2025/matchlogs/all_comps/shooting/Manchester-City-Match-Logs-All-Competitions',
#  '/en/squads/b8fd03ef/2024-2025/matchlogs/all_comps/shooting/Manchester-City-Match-Logs-All-Competitions',
#  '/en/squads/b8fd03ef/2024-2025/matchlogs/all_comps/shooting/Manchester-City-Match-Logs-All-Competitions']

# %%
data = requests.get(f"https://fbref.com{links[0]}") #again adds the missing root to the urls

# %%
shooting = pd.read_html(data.text, match="Shooting")[0]
# Out:
# /var/folders/j5/65jgd4793tvg7jn64hwhwwhm0000gn/T/ipykernel_2291/2517714723.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match="Shooting")[0]

# %%
shooting.head()
# Out:
#   For Manchester City                                                        \
#                  Date   Time                 Comp                Round  Day
# 0          2024-08-10  15:00  FA Community Shield  FA Community Shield  Sat
# 1          2024-08-18  16:30       Premier League          Matchweek 1  Sun
# 2          2024-08-24  15:00       Premier League          Matchweek 2  Sat
# 3          2024-08-31  17:30       Premier League          Matchweek 3  Sat
# 4                 NaN    NaN                  NaN                  NaN  NaN
#
#                                               ... Standard                \
#   Venue Result     GF     GA        Opponent  ...     Dist   FK PK PKatt
# 0  Home      D  1 (7)  1 (6)  Manchester Utd  ...      NaN  NaN  0     0
# 1  Away      W      2      0         Chelsea  ...     19.1  0.0  0     0
# 2  Home      W      4      1    Ipswich Town  ...     17.8  1.0  1     1
# ...

# %%
shooting.columns = shooting.columns.droplevel()

# %%
shooting.head()
# Out:
#          Date   Time                 Comp                Round  Day Venue  \
# 0  2024-08-10  15:00  FA Community Shield  FA Community Shield  Sat  Home
# 1  2024-08-18  16:30       Premier League          Matchweek 1  Sun  Away
# 2  2024-08-24  15:00       Premier League          Matchweek 2  Sat  Home
# 3  2024-08-31  17:30       Premier League          Matchweek 3  Sat  Away
# 4         NaN    NaN                  NaN                  NaN  NaN   NaN
#
#   Result     GF     GA        Opponent  ...  Dist   FK  PK  PKatt   xG  npxG  \
# 0      D  1 (7)  1 (6)  Manchester Utd  ...   NaN  NaN   0      0  NaN   NaN
# 1      W      2      0         Chelsea  ...  19.1  0.0   0      0  0.8   0.8
# 2      W      4      1    Ipswich Town  ...  17.8  1.0   1      1  3.3   2.6
# 3      W      3      1        West Ham  ...  15.0  1.0   0      0  3.0   3.0
# 4     --    NaN    NaN             NaN  ...  16.7  2.0   1      1  NaN   NaN
#
#    npxG/Sh  G-xG  np:G-xG  Match Report
# ...

# %%
#Now we are going to merge both data frames together
team_data = matches[0].merge(shooting[["Date","Sh","SoT","Dist", "FK","PK","PKatt"]], on="Date")

# %%
team_data.head()
# Out:
#          Date   Time                 Comp                Round  Day Venue  \
# 0  2024-08-10  15:00  FA Community Shield  FA Community Shield  Sat  Home
# 1  2024-08-18  16:30       Premier League          Matchweek 1  Sun  Away
# 2  2024-08-24  15:00       Premier League          Matchweek 2  Sat  Home
# 3  2024-08-31  17:30       Premier League          Matchweek 3  Sat  Away
#
#   Result     GF     GA        Opponent  ...  Opp Formation         Referee  \
# 0      D  1 (7)  1 (6)  Manchester Utd  ...        4-2-3-1  Jarred Gillett
# 1      W      2      0         Chelsea  ...        4-2-3-1             NaN
# 2      W      4      1    Ipswich Town  ...          5-4-1             NaN
# 3      W      3      1        West Ham  ...        4-2-3-1  Michael Oliver
#
#    Match Report                                              Notes  Sh SoT  \
# 0  Match Report  Manchester City won on penalty kicks following...   9   1
# ...

# %%
team_data
# Out:
#          Date   Time                 Comp                Round  Day Venue  \
# 0  2024-08-10  15:00  FA Community Shield  FA Community Shield  Sat  Home
# 1  2024-08-18  16:30       Premier League          Matchweek 1  Sun  Away
# 2  2024-08-24  15:00       Premier League          Matchweek 2  Sat  Home
# 3  2024-08-31  17:30       Premier League          Matchweek 3  Sat  Away
#
#   Result     GF     GA        Opponent  ...  Opp Formation         Referee  \
# 0      D  1 (7)  1 (6)  Manchester Utd  ...        4-2-3-1  Jarred Gillett
# 1      W      2      0         Chelsea  ...        4-2-3-1             NaN
# 2      W      4      1    Ipswich Town  ...          5-4-1             NaN
# 3      W      3      1        West Ham  ...        4-2-3-1  Michael Oliver
#
#    Match Report                                              Notes  Sh SoT  \
# 0  Match Report  Manchester City won on penalty kicks following...   9   1
# ...

# %%
#
years = list(range(2024,2022, -1))

# %%
years
# Out:
# [2024, 2023]

# %%
import time

#Iterate over each year
for year in years:
    data = requests.get(standings_url)
    soup = BeautifulSoup(data.text, 'html.parser')
    league_table = soup.select('table.stats_table')[0]

    links = [l.get("href") for l in league_table.find_all('a')]
    links = [l for l in links if '/squads/' in l]# Filter links to only include those related to team squads
    team_urls = [f"https://fbref.com{l}" for l in links]
    
    # Get the URL for the previous season standings
    previous_season = soup.select("a.prev")[0].get("href")
    standings_url = f"https://fbref.com{previous_season}"
    
    # Iterate over each team's URL
    for team_url in team_urls:
        team_name = team_url.split("/")[-1].replace("-Stats", "").replace("-", " ")
        data = requests.get(team_url)
        matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
        soup = BeautifulSoup(data.text, 'html.parser')
        links = [l.get("href") for l in soup.find_all('a')]
        links = [l for l in links if l and 'all_comps/shooting/' in l] #Filter links to only include those related to shooting statistics
        data = requests.get(f"https://fbref.com{links[0]}")
        shooting = pd.read_html(data.text, match="Shooting")[0] # Extract shooting statistics
        shooting.columns = shooting.columns.droplevel()

        #sometimes data is missing so we will use a try block to ignore these scenarios
        try:
            team_data = matches.merge(shooting[["Date", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]], on="Date")
        except ValueError:
            continue
            
        # Filter data to only include Premier League matches
        team_data = team_data[team_data["Comp"] == "Premier League"]
        
        # Add season and team name columns to the data
        team_data["Season"] = year
        team_data["Team"] = team_name
        all_matches.append(team_data)
        
        # Pause for 15 seconds to avoid overwhelming the server with requests
        time.sleep(15)

# %%
all_matches = []

# %%
standings_url = "https://fbref.com/en/comps/9/Premier-League-Stats"

# %%
match_df = pd.concat(all_matches)

# %%
match_df.columns = [c.lower() for c in match_df.columns]

# %%
match_df.to_csv("matches.csv")

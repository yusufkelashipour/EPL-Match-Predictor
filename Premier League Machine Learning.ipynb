# %%
import pandas as pd

# %%
#read data sheet we previously made web scrapping
matches = pd.read_csv("matches.csv", index_col = 0)

# %%
matches.head()
# Out:
#          date   time            comp        round  day venue result   gf   ga  \
# 1  2024-08-18  16:30  Premier League  Matchweek 1  Sun  Away      W  2.0  0.0
# 2  2024-08-24  15:00  Premier League  Matchweek 2  Sat  Home      W  4.0  1.0
# 3  2024-08-31  17:30  Premier League  Matchweek 3  Sat  Away      W  3.0  1.0
# 0  2024-08-17  15:00  Premier League  Matchweek 1  Sat  Away      W  3.0  0.0
# 1  2024-08-24  12:30  Premier League  Matchweek 2  Sat  Home      W  2.0  1.0
#
#          opponent  ...  match report  notes    sh  sot  dist   fk pk pkatt  \
# 1         Chelsea  ...  Match Report    NaN  11.0  5.0  19.1  0.0  0     0
# 2    Ipswich Town  ...  Match Report    NaN  13.0  4.0  17.8  1.0  1     1
# 3        West Ham  ...  Match Report    NaN  23.0  8.0  15.0  1.0  0     0
# 0         Everton  ...  Match Report    NaN  10.0  5.0  13.8  0.0  0     0
# 1  Manchester Utd  ...  Match Report    NaN  14.0  4.0  14.2  1.0  0     0
#
#   season                      team
# ...

# %%
matches.shape
# Out:
# (820, 28)

# %%
#search for missing data
matches["team"].value_counts()
# Out:
# team
# Manchester City             41
# Newcastle United            41
# Everton                     41
# Crystal Palace              41
# Wolverhampton Wanderers     41
# West Ham United             41
# Manchester United           41
# Brighton and Hove Albion    41
# Fulham                      41
# Chelsea                     41
# Tottenham Hotspur           41
# Nottingham Forest           41
# Bournemouth                 41
# Aston Villa                 41
# Brentford                   41
# Liverpool                   41
# Arsenal                     41
# Luton Town                  38
# Burnley                     38
# Sheffield United            38
# Leicester City               3
# Ipswich Town                 3
# Southampton                  3
# Name: count, dtype: int64

# %%
matches[matches["team"] == "Southampton"]
# Out:
#          date   time            comp        round  day venue result   gf   ga  \
# 0  2024-08-17  15:00  Premier League  Matchweek 1  Sat  Away      L  0.0  1.0
# 1  2024-08-24  15:00  Premier League  Matchweek 2  Sat  Home      L  0.0  1.0
# 3  2024-08-31  15:00  Premier League  Matchweek 3  Sat  Away      L  1.0  3.0
#
#           opponent  ...  match report  notes    sh  sot  dist   fk pk pkatt  \
# 0    Newcastle Utd  ...  Match Report    NaN  19.0  3.0  17.0  1.0  0     0
# 1  Nott'ham Forest  ...  Match Report    NaN   5.0  1.0  19.7  0.0  0     0
# 3        Brentford  ...  Match Report    NaN  18.0  6.0  18.1  1.0  0     0
#
#   season         team
# 0   2024  Southampton
# 1   2024  Southampton
# 3   2024  Southampton
#
# [3 rows x 28 columns]

# %%
#begin cleaning data to prepare for machine learning
matches["round"].value_counts()
# Out:
# round
# Matchweek 1     40
# Matchweek 3     40
# Matchweek 2     40
# Matchweek 34    20
# Matchweek 28    20
# Matchweek 23    20
# Matchweek 24    20
# Matchweek 25    20
# Matchweek 18    20
# Matchweek 26    20
# Matchweek 27    20
# Matchweek 30    20
# Matchweek 37    20
# Matchweek 22    20
# Matchweek 32    20
# Matchweek 33    20
# Matchweek 29    20
# Matchweek 35    20
# Matchweek 36    20
# Matchweek 31    20
# Matchweek 21    20
# Matchweek 20    20
# Matchweek 10    20
# Matchweek 4     20
# Matchweek 5     20
# Matchweek 6     20
# Matchweek 7     20
# Matchweek 8     20
# Matchweek 9     20
# Matchweek 11    20
# Matchweek 19    20
# Matchweek 12    20
# Matchweek 13    20
# Matchweek 14    20
# Matchweek 15    20
# Matchweek 16    20
# Matchweek 17    20
# Matchweek 38    20
# Name: count, dtype: int64

# %%
#variables must be in float or int type value
matches.dtypes
# Out:
# date              object
# time              object
# comp              object
# round             object
# day               object
# venue             object
# result            object
# gf               float64
# ga               float64
# opponent          object
# xg               float64
# xga              float64
# poss             float64
# attendance       float64
# captain           object
# formation         object
# opp formation     object
# referee           object
# match report      object
# notes            float64
# sh               float64
# sot              float64
# dist             float64
# fk               float64
# pk                 int64
# pkatt              int64
# season             int64
# team              object
# dtype: object

# %%
#converts date to numerical value
matches["date"] = pd.to_datetime(matches["date"])

# %%
#converts venue value to a number to be analyzed. 
matches["venue_code"] = matches["venue"].astype("category").cat.codes

# %%
matches["opp_code"] = matches["opponent"].astype("category").cat.codes

# %%
#converts hour to exact integer to analyze certain trends at given times
matches["hour"] = matches["time"].str.replace(":.+","", regex=True).astype("int")

# %%
#converts day played to respective integer to be analyzed
matches["day_code"] = matches["date"].dt.dayofweek

# %%
#converts result of game to 1 if won or drawed, and 0 if lost
matches["target"] = (matches["result"] == "W").astype("int")

# %%
matches
# Out:
#          date   time            comp         round  day venue result   gf  \
# 1  2024-08-18  16:30  Premier League   Matchweek 1  Sun  Away      W  2.0
# 2  2024-08-24  15:00  Premier League   Matchweek 2  Sat  Home      W  4.0
# 3  2024-08-31  17:30  Premier League   Matchweek 3  Sat  Away      W  3.0
# 0  2024-08-17  15:00  Premier League   Matchweek 1  Sat  Away      W  3.0
# 1  2024-08-24  12:30  Premier League   Matchweek 2  Sat  Home      W  2.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 36 2024-04-24  20:00  Premier League  Matchweek 29  Wed  Away      L  2.0
# 37 2024-04-27  15:00  Premier League  Matchweek 35  Sat  Away      L  1.0
# 38 2024-05-04  15:00  Premier League  Matchweek 36  Sat  Home      L  1.0
# 39 2024-05-11  15:00  Premier League  Matchweek 37  Sat  Away      L  0.0
# 40 2024-05-19  16:00  Premier League  Matchweek 38  Sun  Home      L  0.0
#
#      ga         opponent  ...   fk  pk  pkatt  season  \
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators = 50, min_samples_split=10, random_state = 1)

# %%
train = matches[matches["date"] < '2024-01-01']

# %%
test = matches[matches["date"] > '2024-01-01']

# %%
predictors = ["venue_code", "opp_code", "hour", "day_code"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(test["target"],preds)

# %%
acc
# Out:
# 0.6032863849765259

# %%
combined = pd.DataFrame(dict(actual=test["target"], prediction = preds))

# %%
pd.crosstab(index = combined["actual"], columns = combined["prediction"])
# Out:
# prediction    0   1
# actual
# 0           200  66
# 1           103  57

# %%
from sklearn.metrics import precision_score

# %%
precision_score(test["target"],preds)
# Out:
# 0.4634146341463415

# %%
grouped_matches = matches.groupby("team")

# %%
group = grouped_matches.get_group("Manchester City")

# %%
group
# Out:
#          date   time            comp         round  day venue result   gf  \
# 1  2024-08-18  16:30  Premier League   Matchweek 1  Sun  Away      W  2.0
# 2  2024-08-24  15:00  Premier League   Matchweek 2  Sat  Home      W  4.0
# 3  2024-08-31  17:30  Premier League   Matchweek 3  Sat  Away      W  3.0
# 1  2023-08-11  20:00  Premier League   Matchweek 1  Fri  Away      W  3.0
# 3  2023-08-19  20:00  Premier League   Matchweek 2  Sat  Home      W  1.0
# 4  2023-08-27  14:00  Premier League   Matchweek 3  Sun  Away      W  2.0
# 5  2023-09-02  15:00  Premier League   Matchweek 4  Sat  Home      W  5.0
# 6  2023-09-16  15:00  Premier League   Matchweek 5  Sat  Away      W  3.0
# 8  2023-09-23  15:00  Premier League   Matchweek 6  Sat  Home      W  2.0
# 10 2023-09-30  15:00  Premier League   Matchweek 7  Sat  Away      L  1.0
# 12 2023-10-08  16:30  Premier League   Matchweek 8  Sun  Away      L  0.0
# 13 2023-10-21  15:00  Premier League   Matchweek 9  Sat  Home      W  2.0
# ...

# %%
#now were going to account for rolling averages, to create a more precise prediction
#for example if a team has lost 3 games in a row, they are more likely to lose the next game, or vice versa
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed = 'left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
#which statistics rolling average should be applied for
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]

# %%
new_cols
# Out:
# ['gf_rolling',
#  'ga_rolling',
#  'sh_rolling',
#  'sot_rolling',
#  'dist_rolling',
#  'fk_rolling',
#  'pk_rolling',
#  'pkatt_rolling']

# %%
rolling_averages(group , cols, new_cols)
# Out:
#          date   time            comp         round  day venue result   gf  \
# 5  2023-09-02  15:00  Premier League   Matchweek 4  Sat  Home      W  5.0
# 6  2023-09-16  15:00  Premier League   Matchweek 5  Sat  Away      W  3.0
# 8  2023-09-23  15:00  Premier League   Matchweek 6  Sat  Home      W  2.0
# 10 2023-09-30  15:00  Premier League   Matchweek 7  Sat  Away      L  1.0
# 12 2023-10-08  16:30  Premier League   Matchweek 8  Sun  Away      L  0.0
# 13 2023-10-21  15:00  Premier League   Matchweek 9  Sat  Home      W  2.0
# 15 2023-10-29  15:30  Premier League  Matchweek 10  Sun  Away      W  3.0
# 16 2023-11-04  15:00  Premier League  Matchweek 11  Sat  Home      W  6.0
# 18 2023-11-12  16:30  Premier League  Matchweek 12  Sun  Away      D  4.0
# 19 2023-11-25  12:30  Premier League  Matchweek 13  Sat  Home      D  1.0
# 21 2023-12-03  16:30  Premier League  Matchweek 14  Sun  Home      D  3.0
# 22 2023-12-06  20:15  Premier League  Matchweek 15  Wed  Away      L  0.0
# ...

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))
# Out:
# /var/folders/j5/65jgd4793tvg7jn64hwhwwhm0000gn/T/ipykernel_83639/4052147919.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
matches_rolling
# Out:
#                                  date   time            comp         round  \
# team
# Arsenal                 4  2023-09-03  16:30  Premier League   Matchweek 4
#                         5  2023-09-17  16:30  Premier League   Matchweek 5
#                         7  2023-09-24  14:00  Premier League   Matchweek 6
#                         9  2023-09-30  15:00  Premier League   Matchweek 7
#                         11 2023-10-08  16:30  Premier League   Matchweek 8
# ...                               ...    ...             ...           ...
# Wolverhampton Wanderers 43 2024-05-11  15:00  Premier League  Matchweek 37
#                         44 2024-05-19  16:00  Premier League  Matchweek 38
#                         0  2024-08-17  15:00  Premier League   Matchweek 1
#                         1  2024-08-25  14:00  Premier League   Matchweek 2
#                         3  2024-08-31  15:00  Premier League   Matchweek 3
#
# ...

# %%
matches_rolling = matches_rolling.droplevel('team')

# %%
matches_rolling
# Out:
#          date   time            comp         round  day venue result   gf  \
# 4  2023-09-03  16:30  Premier League   Matchweek 4  Sun  Home      W  3.0
# 5  2023-09-17  16:30  Premier League   Matchweek 5  Sun  Away      W  1.0
# 7  2023-09-24  14:00  Premier League   Matchweek 6  Sun  Home      D  2.0
# 9  2023-09-30  15:00  Premier League   Matchweek 7  Sat  Away      W  4.0
# 11 2023-10-08  16:30  Premier League   Matchweek 8  Sun  Home      W  1.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 43 2024-05-11  15:00  Premier League  Matchweek 37  Sat  Home      L  1.0
# 44 2024-05-19  16:00  Premier League  Matchweek 38  Sun  Away      L  0.0
# 0  2024-08-17  15:00  Premier League   Matchweek 1  Sat  Away      L  0.0
# 1  2024-08-25  14:00  Premier League   Matchweek 2  Sun  Home      L  2.0
# 3  2024-08-31  15:00  Premier League   Matchweek 3  Sat  Away      D  1.0
#
#      ga         opponent  ...  day_code  target  gf_rolling  ga_rolling  \
# ...

# %%
matches_rolling.index = range(matches_rolling.shape[0])

# %%
matches_rolling
# Out:
#           date   time            comp         round  day venue result   gf  \
# 0   2023-09-03  16:30  Premier League   Matchweek 4  Sun  Home      W  3.0
# 1   2023-09-17  16:30  Premier League   Matchweek 5  Sun  Away      W  1.0
# 2   2023-09-24  14:00  Premier League   Matchweek 6  Sun  Home      D  2.0
# 3   2023-09-30  15:00  Premier League   Matchweek 7  Sat  Away      W  4.0
# 4   2023-10-08  16:30  Premier League   Matchweek 8  Sun  Home      W  1.0
# ..         ...    ...             ...           ...  ...   ...    ...  ...
# 746 2024-05-11  15:00  Premier League  Matchweek 37  Sat  Home      L  1.0
# 747 2024-05-19  16:00  Premier League  Matchweek 38  Sun  Away      L  0.0
# 748 2024-08-17  15:00  Premier League   Matchweek 1  Sat  Away      L  0.0
# 749 2024-08-25  14:00  Premier League   Matchweek 2  Sun  Home      L  2.0
# 750 2024-08-31  15:00  Premier League   Matchweek 3  Sat  Away      D  1.0
#
# ...

# %%
def make_predictions(data,predictors):
    train = matches[matches["date"] < '2024-01-01']
    test = matches[matches["date"] > '2024-01-01']
    rf.fit(train[predictors], train["target"])
    preds =rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted = preds), index=test.index)
    precision = precision_score(test["target"], preds)
    return combined,precision

# %%
combined, precision = make_predictions(matches_rolling, predictors + new_cols)
# Out:
# '%r'

# %%
combined
# Out:
#     actual  prediction
# 1        1           0
# 2        1           0
# 3        1           0
# 0        1           1
# 1        1           0
# ..     ...         ...
# 36       0           0
# 37       0           0
# 38       0           1
# 39       0           1
# 40       0           0
#
# [426 rows x 2 columns]

# %%
scikit-learnimport= combined.merge(matches_rolling[["date","team", "opponent", "result"]], left_index = True, right_index = True)

# %%
combined
# Out:
#     actual  prediction       date         team        opponent result
# 1        1           0 2023-09-17      Arsenal         Everton      W
# 2        1           0 2023-09-24      Arsenal       Tottenham      D
# 3        1           0 2023-09-30      Arsenal     Bournemouth      W
# 0        1           1 2023-09-03      Arsenal  Manchester Utd      W
# 1        1           0 2023-09-17      Arsenal         Everton      W
# ..     ...         ...        ...          ...             ...    ...
# 36       0           0 2024-08-24      Arsenal     Aston Villa      W
# 37       0           0 2024-08-31      Arsenal        Brighton      D
# 38       0           1 2023-09-03  Aston Villa       Liverpool      L
# 39       0           1 2023-09-16  Aston Villa  Crystal Palace      W
# 40       0           0 2023-09-24  Aston Villa         Chelsea      W
#
# [426 rows x 6 columns]
